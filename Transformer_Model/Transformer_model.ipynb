# %%
import os
from sklearn.model_selection import train_test_split

root_dir = "/workspace/Transformer/Databig"  # Replace with your root folder path
labels = {"Adware": 1, "Bankingware": 2, "Benign": 0, "Smsware": 3, "Riskware": 4}
data = []
target = []

# Extract data and labels
for label_name, label_id in labels.items():
    folder_path = os.path.join(root_dir, label_name)
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.txt'):
            with open(os.path.join(folder_path, file_name), 'r') as file:
                syscall_sequence = file.read().strip().split()  # List of syscalls
                data.append(syscall_sequence)
                target.append(label_id)  # Numerical label

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

# %%
from collections import Counter

# Flatten all sequences to create a vocabulary
all_syscalls = [syscall for sequence in data for syscall in sequence]
syscall_counts = Counter(all_syscalls)
vocab = {syscall: idx + 1 for idx, syscall in enumerate(syscall_counts.keys())}  # Start index from 1

# %%
# Convert syscall sequences in train and test data to integer IDs
X_train_tokenized = [[vocab[syscall] for syscall in sequence if syscall in vocab] for sequence in X_train]
X_test_tokenized = [[vocab[syscall] for syscall in sequence if syscall in vocab] for sequence in X_test]

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_seq_length = 1000 # Define a maximum sequence length based on your dataset

# Pad sequences
X_train_padded = pad_sequences(X_train_tokenized, maxlen=max_seq_length, padding='post', truncating='post')
X_test_padded = pad_sequences(X_test_tokenized, maxlen=max_seq_length, padding='post', truncating='post')
# Out:
# 2024-11-22 05:40:43.082608: E external/local_xla/xla/stream_executor/plugin_registry.cc:91] Invalid plugin kind specified: FFT
# 2024-11-22 05:40:43.362363: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-22 05:40:45.159711: E external/local_xla/xla/stream_executor/plugin_registry.cc:91] Invalid plugin kind specified: DNN
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.20) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, Dense, Dropout, GlobalAveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization, Add

# Transformer block
def transformer_block(inputs, num_heads, ff_dim, dropout_rate):
    # Multi-head attention
    attention_output = MultiHeadAttention(num_heads=num_heads, key_dim=ff_dim)(inputs, inputs)
    attention_output = Dropout(dropout_rate)(attention_output)
    attention_output = Add()([inputs, attention_output])
    attention_output = LayerNormalization(epsilon=1e-6)(attention_output)
    
    # Feed-forward network
    ffn_output = Dense(ff_dim, activation="relu")(attention_output)
    ffn_output = Dense(inputs.shape[-1])(ffn_output)
    ffn_output = Dropout(dropout_rate)(ffn_output)
    ffn_output = Add()([attention_output, ffn_output])
    ffn_output = LayerNormalization(epsilon=1e-6)(ffn_output)
    return ffn_output

# Build Transformer model
def build_transformer_model(vocab_size, max_len, embed_dim, num_heads, ff_dim, num_classes, dropout_rate=0.1):
    inputs = Input(shape=(max_len,))  # Define input shape here
    embedding_layer = Embedding(input_dim=vocab_size + 1, output_dim=embed_dim)(inputs)  # Removed `input_length`
    
    # Add transformer blocks
    x = transformer_block(embedding_layer, num_heads=num_heads, ff_dim=ff_dim, dropout_rate=dropout_rate)
    x = GlobalAveragePooling1D()(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(256, activation="relu")(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(num_classes, activation="softmax")(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Parameters for the model
embed_dim = 256
num_heads = 4
ff_dim = 128
num_classes = len(labels)
dropout_rate = 0

# Instantiate and compile the model
model = build_transformer_model(len(vocab), max_seq_length, embed_dim, num_heads, ff_dim, num_classes, dropout_rate)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# 2024-11-22 05:40:47.839437: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:47.839506: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.069245: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.069303: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.069339: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.069378: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.069388: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2306] Ignoring visible gpu device (device: 1, name: AMD Radeon Graphics, pci bus id: 0000:13:00.0) with AMDGPU version : gfx1036. The supported AMDGPU versions are gfx900, gfx906, gfx908, gfx90a, gfx940, gfx941, gfx942, gfx1030, gfx1100.
# 2024-11-22 05:40:48.070042: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.070107: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.070137: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.070385: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.070422: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.070457: I external/local_xla/xla/stream_executor/rocm/rocm_executor.cc:926] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-11-22 05:40:48.070473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15306 MB memory:  -> device: 0, name: Radeon RX 7900 GRE, pci bus id: 0000:03:00.0

# %%
import numpy as np

# Ensure the input data is in NumPy array format
X_train_padded = np.array(X_train_padded)
y_train = np.array(y_train)

# Train the Transformer model
history = model.fit(X_train_padded, y_train, epochs=100, batch_size=16, validation_split=0.1)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732254049.696345    1672 service.cc:145] XLA service 0x7a7eb40157c0 initialized for platform ROCM (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1732254049.696370    1672 service.cc:153]   StreamExecutor device (0): Radeon RX 7900 GRE, AMDGPU ISA version: gfx1100
# 2024-11-22 05:40:49.745341: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
#   7/264 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.2349 - loss: 2.1285
# I0000 00:00:1732254065.995685    1672 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 32s 56ms/step - accuracy: 0.5075 - loss: 1.2455 - val_accuracy: 0.6389 - val_loss: 0.9814
# Epoch 2/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.6709 - loss: 0.9026 - val_accuracy: 0.7244 - val_loss: 0.8267
# Epoch 3/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.7367 - loss: 0.7290 - val_accuracy: 0.6859 - val_loss: 0.9871
# Epoch 4/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.7557 - loss: 0.6923 - val_accuracy: 0.7350 - val_loss: 0.7145
# Epoch 5/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.7738 - loss: 0.6148 - val_accuracy: 0.7821 - val_loss: 0.6882
# Epoch 6/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.7675 - loss: 0.6378 - val_accuracy: 0.7778 - val_loss: 0.7415
# Epoch 7/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8029 - loss: 0.5595 - val_accuracy: 0.7927 - val_loss: 0.6492
# Epoch 8/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8146 - loss: 0.5237 - val_accuracy: 0.8226 - val_loss: 0.5609
# Epoch 9/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8351 - loss: 0.4819 - val_accuracy: 0.8034 - val_loss: 0.6425
# Epoch 10/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8085 - loss: 0.5160 - val_accuracy: 0.8098 - val_loss: 0.6258
# Epoch 11/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8378 - loss: 0.4782 - val_accuracy: 0.7991 - val_loss: 0.6002
# Epoch 12/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8409 - loss: 0.4610 - val_accuracy: 0.8077 - val_loss: 0.6603
# Epoch 13/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8428 - loss: 0.4466 - val_accuracy: 0.8269 - val_loss: 0.5506
# Epoch 14/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8382 - loss: 0.4581 - val_accuracy: 0.7906 - val_loss: 0.6363
# Epoch 15/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8450 - loss: 0.4529 - val_accuracy: 0.8184 - val_loss: 0.5743
# Epoch 16/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8563 - loss: 0.4045 - val_accuracy: 0.8291 - val_loss: 0.6035
# Epoch 17/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8609 - loss: 0.3784 - val_accuracy: 0.8312 - val_loss: 0.5933
# Epoch 18/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8586 - loss: 0.4065 - val_accuracy: 0.8034 - val_loss: 0.5926
# Epoch 19/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8573 - loss: 0.4101 - val_accuracy: 0.8205 - val_loss: 0.5681
# Epoch 20/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8766 - loss: 0.3883 - val_accuracy: 0.8397 - val_loss: 0.5214
# Epoch 21/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8650 - loss: 0.3779 - val_accuracy: 0.8376 - val_loss: 0.5828
# Epoch 22/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8571 - loss: 0.3912 - val_accuracy: 0.8419 - val_loss: 0.5375
# Epoch 23/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8759 - loss: 0.3587 - val_accuracy: 0.8291 - val_loss: 0.5265
# Epoch 24/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8697 - loss: 0.3703 - val_accuracy: 0.8397 - val_loss: 0.5243
# Epoch 25/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8704 - loss: 0.3628 - val_accuracy: 0.8226 - val_loss: 0.5557
# Epoch 26/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8793 - loss: 0.3412 - val_accuracy: 0.8718 - val_loss: 0.5045
# Epoch 27/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8728 - loss: 0.3543 - val_accuracy: 0.8526 - val_loss: 0.5481
# Epoch 28/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8709 - loss: 0.3359 - val_accuracy: 0.8355 - val_loss: 0.5570
# Epoch 29/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8654 - loss: 0.3630 - val_accuracy: 0.8462 - val_loss: 0.5697
# Epoch 30/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8887 - loss: 0.3307 - val_accuracy: 0.8291 - val_loss: 0.5805
# Epoch 31/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8851 - loss: 0.3356 - val_accuracy: 0.8355 - val_loss: 0.6345
# Epoch 32/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8813 - loss: 0.3242 - val_accuracy: 0.8376 - val_loss: 0.5811
# Epoch 33/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8766 - loss: 0.3311 - val_accuracy: 0.8568 - val_loss: 0.5278
# Epoch 34/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8870 - loss: 0.3113 - val_accuracy: 0.8397 - val_loss: 0.5823
# Epoch 35/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8862 - loss: 0.3183 - val_accuracy: 0.8462 - val_loss: 0.5970
# Epoch 36/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9009 - loss: 0.2887 - val_accuracy: 0.8312 - val_loss: 0.5713
# Epoch 37/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8844 - loss: 0.2999 - val_accuracy: 0.8077 - val_loss: 0.7492
# Epoch 38/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8990 - loss: 0.3040 - val_accuracy: 0.8333 - val_loss: 0.6291
# Epoch 39/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8797 - loss: 0.3296 - val_accuracy: 0.8120 - val_loss: 0.7407
# Epoch 40/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8164 - loss: 0.5498 - val_accuracy: 0.8248 - val_loss: 0.6430
# Epoch 41/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8901 - loss: 0.3205 - val_accuracy: 0.8226 - val_loss: 0.6448
# Epoch 42/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8853 - loss: 0.3068 - val_accuracy: 0.8568 - val_loss: 0.5791
# Epoch 43/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9043 - loss: 0.2693 - val_accuracy: 0.8248 - val_loss: 0.6307
# Epoch 44/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9085 - loss: 0.2663 - val_accuracy: 0.8226 - val_loss: 0.6800
# Epoch 45/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8875 - loss: 0.2910 - val_accuracy: 0.8526 - val_loss: 0.6386
# Epoch 46/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9086 - loss: 0.2534 - val_accuracy: 0.8462 - val_loss: 0.6364
# Epoch 47/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9054 - loss: 0.2712 - val_accuracy: 0.8739 - val_loss: 0.5600
# Epoch 48/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9078 - loss: 0.2648 - val_accuracy: 0.8205 - val_loss: 0.7003
# Epoch 49/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8936 - loss: 0.2940 - val_accuracy: 0.8697 - val_loss: 0.6282
# Epoch 50/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9084 - loss: 0.2589 - val_accuracy: 0.8162 - val_loss: 0.6256
# Epoch 51/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9101 - loss: 0.2559 - val_accuracy: 0.8739 - val_loss: 0.6112
# Epoch 52/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8983 - loss: 0.2720 - val_accuracy: 0.8526 - val_loss: 0.6618
# Epoch 53/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9000 - loss: 0.2711 - val_accuracy: 0.8462 - val_loss: 0.5415
# Epoch 54/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9101 - loss: 0.2470 - val_accuracy: 0.8611 - val_loss: 0.6127
# Epoch 55/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9023 - loss: 0.2639 - val_accuracy: 0.8675 - val_loss: 0.5692
# Epoch 56/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9129 - loss: 0.2524 - val_accuracy: 0.8333 - val_loss: 0.5806
# Epoch 57/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8934 - loss: 0.2730 - val_accuracy: 0.8697 - val_loss: 0.5980
# Epoch 58/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9029 - loss: 0.2739 - val_accuracy: 0.8568 - val_loss: 0.6561
# Epoch 59/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9042 - loss: 0.2667 - val_accuracy: 0.8782 - val_loss: 0.6141
# Epoch 60/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9169 - loss: 0.2317 - val_accuracy: 0.8654 - val_loss: 0.6406
# Epoch 61/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9119 - loss: 0.2504 - val_accuracy: 0.8611 - val_loss: 0.6400
# Epoch 62/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9096 - loss: 0.2479 - val_accuracy: 0.8718 - val_loss: 0.5554
# Epoch 63/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9280 - loss: 0.2047 - val_accuracy: 0.8547 - val_loss: 0.7077
# Epoch 64/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8994 - loss: 0.2787 - val_accuracy: 0.8632 - val_loss: 0.6959
# Epoch 65/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9050 - loss: 0.2574 - val_accuracy: 0.8846 - val_loss: 0.5410
# Epoch 66/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.8896 - loss: 0.3051 - val_accuracy: 0.8526 - val_loss: 0.5827
# Epoch 67/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9215 - loss: 0.2091 - val_accuracy: 0.8782 - val_loss: 0.5585
# Epoch 68/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9147 - loss: 0.2152 - val_accuracy: 0.8654 - val_loss: 0.6393
# Epoch 69/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9198 - loss: 0.2230 - val_accuracy: 0.8291 - val_loss: 0.7626
# Epoch 70/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9066 - loss: 0.2457 - val_accuracy: 0.8547 - val_loss: 0.6360
# Epoch 71/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9218 - loss: 0.2305 - val_accuracy: 0.8440 - val_loss: 0.5847
# Epoch 72/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9251 - loss: 0.2087 - val_accuracy: 0.8718 - val_loss: 0.6071
# Epoch 73/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9305 - loss: 0.1892 - val_accuracy: 0.8697 - val_loss: 0.6110
# Epoch 74/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9137 - loss: 0.2430 - val_accuracy: 0.8803 - val_loss: 0.6454
# Epoch 75/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9231 - loss: 0.2113 - val_accuracy: 0.8697 - val_loss: 0.7146
# Epoch 76/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9289 - loss: 0.2120 - val_accuracy: 0.8761 - val_loss: 0.6063
# Epoch 77/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9404 - loss: 0.1731 - val_accuracy: 0.8675 - val_loss: 0.5921
# Epoch 78/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9307 - loss: 0.2031 - val_accuracy: 0.8868 - val_loss: 0.6443
# Epoch 79/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9299 - loss: 0.2021 - val_accuracy: 0.8654 - val_loss: 0.7222
# Epoch 80/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9277 - loss: 0.1972 - val_accuracy: 0.8632 - val_loss: 0.5905
# Epoch 81/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9246 - loss: 0.2166 - val_accuracy: 0.8226 - val_loss: 0.7461
# Epoch 82/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8951 - loss: 0.3168 - val_accuracy: 0.8675 - val_loss: 0.6762
# Epoch 83/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9379 - loss: 0.1812 - val_accuracy: 0.8590 - val_loss: 0.7196
# Epoch 84/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9251 - loss: 0.1939 - val_accuracy: 0.8846 - val_loss: 0.6768
# Epoch 85/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9355 - loss: 0.1778 - val_accuracy: 0.8526 - val_loss: 0.7513
# Epoch 86/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9368 - loss: 0.1653 - val_accuracy: 0.8590 - val_loss: 0.7312
# Epoch 87/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9453 - loss: 0.1512 - val_accuracy: 0.8611 - val_loss: 0.6955
# Epoch 88/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9356 - loss: 0.1845 - val_accuracy: 0.8803 - val_loss: 0.7572
# Epoch 89/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9426 - loss: 0.1640 - val_accuracy: 0.8718 - val_loss: 0.8605
# Epoch 90/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9218 - loss: 0.2056 - val_accuracy: 0.8803 - val_loss: 0.6349
# Epoch 91/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9201 - loss: 0.2254 - val_accuracy: 0.8419 - val_loss: 0.7043
# Epoch 92/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9267 - loss: 0.2142 - val_accuracy: 0.8718 - val_loss: 0.6437
# Epoch 93/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9263 - loss: 0.2015 - val_accuracy: 0.8675 - val_loss: 0.6817
# Epoch 94/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9411 - loss: 0.1745 - val_accuracy: 0.8739 - val_loss: 0.7700
# Epoch 95/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9447 - loss: 0.1466 - val_accuracy: 0.8568 - val_loss: 0.7796
# Epoch 96/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9310 - loss: 0.1844 - val_accuracy: 0.8889 - val_loss: 0.6142
# Epoch 97/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9416 - loss: 0.1525 - val_accuracy: 0.8697 - val_loss: 0.7555
# Epoch 98/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9494 - loss: 0.1466 - val_accuracy: 0.8397 - val_loss: 0.8806
# Epoch 99/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9181 - loss: 0.2176 - val_accuracy: 0.8697 - val_loss: 0.6870
# Epoch 100/100
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9268 - loss: 0.2058 - val_accuracy: 0.8504 - val_loss: 0.7393

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import numpy as np

# Assuming X_test_padded is the padded test data and y_test is the true labels
y_pred_probs = model.predict(X_test_padded)
y_pred = np.argmax(y_pred_probs, axis=1)  # Get the predicted class labels

# Generate classification report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=['Adware', 'Bankingware', 'Benign', 'Smsware', 'Riskware']))

# Overall accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Overall Accuracy: {accuracy}")

# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
#  1/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#       Adware       0.72      0.83      0.77       221
#  Bankingware       0.84      0.76      0.80       251
#       Benign       0.89      0.84      0.87       254
#      Smsware       0.95      0.97      0.96       233
#     Riskware       0.89      0.89      0.89       211
#
#     accuracy                           0.86      1170
#    macro avg       0.86      0.86      0.86      1170
# weighted avg       0.86      0.86      0.86      1170
#
# Overall Accuracy: 0.8564102564102564
# Confusion Matrix:
# [[184  12   9   4  12]
#  [ 37 191  12   3   8]
#  [ 25   9 213   4   3]
#  [  1   3   1 227   1]
#  [  8  13   3   0 187]]

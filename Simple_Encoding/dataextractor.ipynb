# %%
import os
import json

# Paths
root_dir = '/workspace/JSONs/Capturing-logs/SmsJson'
output_dir = '/workspace/ProcessedSequences/Smsware'
os.makedirs(output_dir, exist_ok=True)

# Load syscall encoding
with open('/workspace/Barebones/unique_syscalls.txt', 'r') as f:
    unique_syscalls = [line.strip() for line in f.readlines()]
syscall_to_index = {syscall: idx for idx, syscall in enumerate(unique_syscalls)}

def process_json_file(file_path):
    data = None
    
    # Attempt to open the file with UTF-8 encoding first, then try 'latin-1' as fallback
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except (UnicodeDecodeError, json.JSONDecodeError):
        print(f"UTF-8 decoding or JSON error for {file_path}. Trying with 'latin-1' encoding.")
        try:
            with open(file_path, 'r', encoding='latin-1') as f:
                data = json.load(f)
        except (UnicodeDecodeError, json.JSONDecodeError):
            print(f"Skipping file due to encoding or JSON format issues: {file_path}")
            return  # Skip this file if both attempts fail
    
    # Proceed with extracting syscalls if data was successfully loaded
    try:
        syscalls = data.get('behaviors', {}).get('dynamic', {}).get('host', [])
        syscall_sequence = []

        for entry in syscalls:
            if entry.get("class") == "SYSCALL" and "low" in entry:
                for low_entry in entry["low"]:
                    sysname = low_entry.get("sysname")
                    if sysname in syscall_to_index:
                        seq_id = low_entry.get("id")
                        syscall_sequence.append((seq_id, syscall_to_index[sysname]))

        syscall_sequence.sort(key=lambda x: x[0])
        encoded_sequence = [entry[1] for entry in syscall_sequence]

        if encoded_sequence:
            output_file = os.path.join(output_dir, f"{os.path.basename(file_path).replace('.json', '_sequence.txt')}")
            with open(output_file, 'w') as out_f:
                out_f.write(" ".join(map(str, encoded_sequence)))

    except KeyError as e:
        print(f"Skipping file due to missing data key {e}: {file_path}")

# Process each JSON file in the directory
for filename in os.listdir(root_dir):
    if filename.endswith('.json'):
        file_path = os.path.join(root_dir, filename)
        process_json_file(file_path)

print("Smsware sequence extraction complete.")
# Out:
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/EBD0E5816B4CD4252A94A7700A3431A5FC0E1D6FE1EB36A198064AFCB533AB82.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/EBD0E5816B4CD4252A94A7700A3431A5FC0E1D6FE1EB36A198064AFCB533AB82.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/B1698885C3D85E3C6F7E2AB94751DC394C0EB08F17093A9D7327FDED76D1E0A3.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/B1698885C3D85E3C6F7E2AB94751DC394C0EB08F17093A9D7327FDED76D1E0A3.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/4951131DA6682276DA6EF866AA5929D7B0E854F2E95442642934DC810C271331.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/4951131DA6682276DA6EF866AA5929D7B0E854F2E95442642934DC810C271331.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/1A1BB570529C00194E00964EB9C318BA2E08FD9F18A1499E3BD80098DED234E2.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/1A1BB570529C00194E00964EB9C318BA2E08FD9F18A1499E3BD80098DED234E2.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/2694D23D0851A7535887AFFDC4443B24555C9AFC99464B7FDF4199A57FF9E9F6.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/2694D23D0851A7535887AFFDC4443B24555C9AFC99464B7FDF4199A57FF9E9F6.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/A834EE00FE2A52933CA721C0E70B67807D0124DC99E30765846946BC4DFD01EB.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/A834EE00FE2A52933CA721C0E70B67807D0124DC99E30765846946BC4DFD01EB.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/36F824BA1B383A10758F29BDF701A97C32BCB71CBB742C4A3ACAB51FE4D8A2AF.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/36F824BA1B383A10758F29BDF701A97C32BCB71CBB742C4A3ACAB51FE4D8A2AF.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/B6732A57B1F35651651164280B37F0330E4F461894EE4528615C67DB658F87D5.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/B6732A57B1F35651651164280B37F0330E4F461894EE4528615C67DB658F87D5.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/F22DF783D74922045755F8B5ABCDFADCC8C3F23589343B362E81D97FA62B54A4.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/F22DF783D74922045755F8B5ABCDFADCC8C3F23589343B362E81D97FA62B54A4.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/DDCBBAE29557D2ADB7F769D9EEE7DD4BBED1AFA80BD53D8F779299DCE70AA76A.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/DDCBBAE29557D2ADB7F769D9EEE7DD4BBED1AFA80BD53D8F779299DCE70AA76A.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/22BCBDAD24FCB3AFB4C6D80223488DD1DBF564F6B8153071F472B5CCC715681D.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/22BCBDAD24FCB3AFB4C6D80223488DD1DBF564F6B8153071F472B5CCC715681D.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/2D373DB71940607009E4124C127F70B23A480F3AC42564EA2C739B5D430ECCBE.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/2D373DB71940607009E4124C127F70B23A480F3AC42564EA2C739B5D430ECCBE.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/1C51AC0A2B657D81B1F88DF3AA85BC2F532D6CEE2FCA930680229074A097E73C.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/1C51AC0A2B657D81B1F88DF3AA85BC2F532D6CEE2FCA930680229074A097E73C.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/F2A35B792E45662310F7E3444CE43EFB55C3C612E3A82CCB10C19435982A6A0F.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/F2A35B792E45662310F7E3444CE43EFB55C3C612E3A82CCB10C19435982A6A0F.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/632F41B8DFB8D39BA770812833FE51DE86DE1810B2E641E52C9BE79F06536009.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/632F41B8DFB8D39BA770812833FE51DE86DE1810B2E641E52C9BE79F06536009.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/676F985D8EDA398085A043E2AE7F55390A34029B831E9B25A991D5D2C1B1353B.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/676F985D8EDA398085A043E2AE7F55390A34029B831E9B25A991D5D2C1B1353B.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/84126E37E133E110901D1E46897180CFFD59215BB4FF035CC5AC805AA4148710.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/84126E37E133E110901D1E46897180CFFD59215BB4FF035CC5AC805AA4148710.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/845570CEFFEEB13FCABB697C790619045E9AEA431B17514C1369FFF07A0F7281.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/845570CEFFEEB13FCABB697C790619045E9AEA431B17514C1369FFF07A0F7281.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/94E23ACF78FC6E0DF826F4B00724192EBB8379AC79901D37D7B8368EEFF79FCF.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/94E23ACF78FC6E0DF826F4B00724192EBB8379AC79901D37D7B8368EEFF79FCF.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/143BFB327045A7745AB04E3E50698C5B7916A2BAFB08513EF6FD33A7F7719702.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/143BFB327045A7745AB04E3E50698C5B7916A2BAFB08513EF6FD33A7F7719702.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/AA67AB97494AAC027435CAC1FC8D424AF7CF6EFFF1D700D50F6BE10636771011.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/AA67AB97494AAC027435CAC1FC8D424AF7CF6EFFF1D700D50F6BE10636771011.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/C9AC522B0B81EE44B95381685E92D5477630070E8B7C97EC15B2206C5A9CBA6E.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/C9AC522B0B81EE44B95381685E92D5477630070E8B7C97EC15B2206C5A9CBA6E.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/0E685DA8FC17C85C37072253378118F6203F50107B5408D1E262ED41D157ABAE.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/0E685DA8FC17C85C37072253378118F6203F50107B5408D1E262ED41D157ABAE.json
# UTF-8 decoding or JSON error for /workspace/JSONs/Capturing-logs/SmsJson/B1D510B3C3D18CE57866B6A26E60ACE12B04DBD95CB6FC171EDB2A3065B5DD1A.json. Trying with 'latin-1' encoding.
# Skipping file due to encoding or JSON format issues: /workspace/JSONs/Capturing-logs/SmsJson/B1D510B3C3D18CE57866B6A26E60ACE12B04DBD95CB6FC171EDB2A3065B5DD1A.json
# Smsware sequence extraction complete.
